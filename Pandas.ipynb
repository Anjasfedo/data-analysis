# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjasfedo/data-analysis/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Intro to DataFrame

# %%
df = pd.DataFrame([[1,2,3],
                   [4,5,6],
                   [6,7,8]],
                  columns=["A","B","C"],
                  index=["x", "y", "z"])

# %%
# Look head
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  6  7  8

# %%
# Look tail
df.tail()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  6  7  8

# %%
# Look the header (columns)
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# Take indexing
df.index.tolist()
# Out:
# ['x', 'y', 'z']

# %%
# Look the information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
# Describing data
df.describe()
# Out:
#               A         B         C
# count  3.000000  3.000000  3.000000
# mean   3.666667  4.666667  5.666667
# std    2.516611  2.516611  2.516611
# min    1.000000  2.000000  3.000000
# 25%    2.500000  3.500000  4.500000
# 50%    4.000000  5.000000  6.000000
# 75%    5.000000  6.000000  7.000000
# max    6.000000  7.000000  8.000000

# %%
# Find number of unique values
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
# Look unique value on specific column
df["A"].unique()
# Out:
# array([1, 4, 6])

# %%
# Know the shape
df.shape
# Out:
# (3, 3)

# %%
# Then the size
df.size
# Out:
# 9

# %%
# Get null value
df.isnull()
# Out:
#        A      B      C
# x  False  False  False
# y  False  False  False
# z  False  False  False

# %% [markdown]
# # Loading in DataFrame from Files

# %% [markdown]
# ## Download the file

# %%
import requests

def download_file(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, 'wb') as file:
            file.write(response.content)

# %%
download_file(url="https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/warmup-data/coffee.csv",
              filename="coffee.csv")

# %% [markdown]
# ## Load to DataFrame

# %%
coffee = pd.read_csv("coffee.csv")

coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# ## Load directly from url

# %%
coffee = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/warmup-data/coffee.csv")

coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# #### CSV, feather, perquet
# based on the large of file CSV > feather > perquet

# %%
bios = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/data/bios.csv")

bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# # Accessing Data

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
# Take sample
coffee.sample(5, random_state=42)
# Out:
#           Day Coffee Type  Units Sold
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 0      Monday    Espresso          25
# 12     Sunday    Espresso          45
# 5   Wednesday       Latte          25

# %%
# loc, filter by row and column [row, col]
coffee.loc[[0]]
# Out:
#       Day Coffee Type  Units Sold
# 0  Monday    Espresso          25

# %%
coffee.loc[[0,1,2]]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
coffee.loc[0:2]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
coffee.loc[5:7, ["Day", "Coffee Type"]]
# Out:
#          Day Coffee Type
# 5  Wednesday       Latte
# 6   Thursday    Espresso
# 7   Thursday       Latte

# %%
# iloc, only access index
coffee.iloc[0:5, [0,2]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
# Access & Change
coffee.loc[1, "Units Sold"] = 10

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
# Grab specific element
coffee.at[0, "Units Sold"]
# Out:
# 25

# %%
# Specific element only use index
coffee.iat[0, 2]
# Out:
# 25

# %%
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.sort_values("Units Sold", ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          10

# %%
coffee.sort_values(["Day", "Units Sold"], ascending=[1, 0])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25

# %%
for index, row in coffee.iterrows():
    print(index)
    print(row)
    print()
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
#
# 9
# ...

# %% [markdown]
# # Filtering Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.shape
# Out:
# (145500, 10)

# %%
bios.loc[bios["height_cm"] > 215].shape
# Out:
# (35, 10)

# %%
bios.loc[bios['height_cm'] > 215, ['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
# Simpler way
bios[bios["height_cm"] > 215].shape
# Out:
# (35, 10)

# %%
bios[bios["height_cm"] > 215][["name", "height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios[(bios["height_cm"] > 215) & (bios["born_country"] == "USA")]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
# String method
bios[bios["name"].str.contains("keith", case=False, regex=False)]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
# Use Regex
bios[bios["name"].str.contains(r"keith|patrick", case=False)]
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
# ` as Not operation
bios[~bios["name"].str.contains(r"son$|sen$", case=False, na=False)]
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios[bios["born_country"].isin(["USA", 'FRA'])]
# Out:
#         athlete_id                   name   born_date      born_city  \
# 0                1  Jean-François Blanchy  1886-12-12       Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01         Meulan
# 2                3           Jean Borotra  1898-08-13       Biarritz
# 3                4        Jacques Brugnon  1895-05-11    Paris VIIIe
# 5                6      Nicolas Chatelain  1970-01-13         Amiens
# ...            ...                    ...         ...            ...
# 145454      149180          Anna Hoffmann  2000-03-28        Madison
# 145457      149183         Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145467      149194            Elisa Nakab  1998-05-08       Briançon
# 145468      149195      Justin Abdelkader  1987-02-25       Muskegon
# 145498      149225         André Foussard  1899-05-19          Niort
#
#                  born_region born_country            NOC  height_cm  \
# 0                    Gironde          FRA         France        NaN
# ...

# %%
bios[bios["born_country"].isin(["USA", "FRA", "GBR"]) & (bios["name"].str.startswith("Keith"))]
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# ...

# %%
# Filter with query
bios.query("born_country in ('USA', 'FRA', 'GBR') and name.str.startswith('Keith')")
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# ...

# %% [markdown]
# # Adding / Removing Column

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee["Price"] = 4.99

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          10   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
import numpy as np

coffee["New Price"] = np.where(coffee["Coffee Type"] == "Espresso", 3.99, 5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  New Price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          10   4.99       5.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
# Dropping
coffee.drop(0)
# Out:
#           Day Coffee Type  Units Sold  Price  New Price
# 1      Monday       Latte          10   4.99       5.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
coffee.drop(columns=["Price"])
# Out:
#           Day Coffee Type  Units Sold  New Price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          10       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
# Drop not access real variable
coffee # coffee still same
# Out:
#           Day Coffee Type  Units Sold  Price  New Price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte          10   4.99       5.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       5.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       5.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       5.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       5.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       5.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          35   4.99       5.99

# %%
# coffee = coffee.drop(columns=["Price"])
coffee.drop(columns=["Price"], inplace=True) # inplace True to modify

coffee
# Out:
#           Day Coffee Type  Units Sold  New Price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          10       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee_new = coffee

# %%
coffee_new["Price"] = 4.99

coffee_new
# Out:
#           Day Coffee Type  Units Sold  New Price  Price
# 0      Monday    Espresso          25       3.99   4.99
# 1      Monday       Latte          10       5.99   4.99
# 2     Tuesday    Espresso          30       3.99   4.99
# 3     Tuesday       Latte          20       5.99   4.99
# 4   Wednesday    Espresso          35       3.99   4.99
# 5   Wednesday       Latte          25       5.99   4.99
# 6    Thursday    Espresso          40       3.99   4.99
# 7    Thursday       Latte          30       5.99   4.99
# 8      Friday    Espresso          45       3.99   4.99
# 9      Friday       Latte          35       5.99   4.99
# 10   Saturday    Espresso          45       3.99   4.99
# 11   Saturday       Latte          35       5.99   4.99
# 12     Sunday    Espresso          45       3.99   4.99
# 13     Sunday       Latte          35       5.99   4.99

# %%
coffee # it also effect the original variable
# Out:
#           Day Coffee Type  Units Sold  New Price  Price
# 0      Monday    Espresso          25       3.99   4.99
# 1      Monday       Latte          10       5.99   4.99
# 2     Tuesday    Espresso          30       3.99   4.99
# 3     Tuesday       Latte          20       5.99   4.99
# 4   Wednesday    Espresso          35       3.99   4.99
# 5   Wednesday       Latte          25       5.99   4.99
# 6    Thursday    Espresso          40       3.99   4.99
# 7    Thursday       Latte          30       5.99   4.99
# 8      Friday    Espresso          45       3.99   4.99
# 9      Friday       Latte          35       5.99   4.99
# 10   Saturday    Espresso          45       3.99   4.99
# 11   Saturday       Latte          35       5.99   4.99
# 12     Sunday    Espresso          45       3.99   4.99
# 13     Sunday       Latte          35       5.99   4.99

# %%
coffee_copy = coffee.copy()

coffee_copy["Price"] = 9.99

coffee_copy
# Out:
#           Day Coffee Type  Units Sold  New Price  Price
# 0      Monday    Espresso          25       3.99   9.99
# 1      Monday       Latte          10       5.99   9.99
# 2     Tuesday    Espresso          30       3.99   9.99
# 3     Tuesday       Latte          20       5.99   9.99
# 4   Wednesday    Espresso          35       3.99   9.99
# 5   Wednesday       Latte          25       5.99   9.99
# 6    Thursday    Espresso          40       3.99   9.99
# 7    Thursday       Latte          30       5.99   9.99
# 8      Friday    Espresso          45       3.99   9.99
# 9      Friday       Latte          35       5.99   9.99
# 10   Saturday    Espresso          45       3.99   9.99
# 11   Saturday       Latte          35       5.99   9.99
# 12     Sunday    Espresso          45       3.99   9.99
# 13     Sunday       Latte          35       5.99   9.99

# %%
coffee # use .copy() to place it into different memory
# Out:
#           Day Coffee Type  Units Sold  New Price  Price
# 0      Monday    Espresso          25       3.99   4.99
# 1      Monday       Latte          10       5.99   4.99
# 2     Tuesday    Espresso          30       3.99   4.99
# 3     Tuesday       Latte          20       5.99   4.99
# 4   Wednesday    Espresso          35       3.99   4.99
# 5   Wednesday       Latte          25       5.99   4.99
# 6    Thursday    Espresso          40       3.99   4.99
# 7    Thursday       Latte          30       5.99   4.99
# 8      Friday    Espresso          45       3.99   4.99
# 9      Friday       Latte          35       5.99   4.99
# 10   Saturday    Espresso          45       3.99   4.99
# 11   Saturday       Latte          35       5.99   4.99
# 12     Sunday    Espresso          45       3.99   4.99
# 13     Sunday       Latte          35       5.99   4.99

# %%
coffee = coffee[['Coffee Type', 'Units Sold', 'New Price']]

coffee
# Out:
#    Coffee Type  Units Sold  New Price
# 0     Espresso          25       3.99
# 1        Latte          10       5.99
# 2     Espresso          30       3.99
# 3        Latte          20       5.99
# 4     Espresso          35       3.99
# 5        Latte          25       5.99
# 6     Espresso          40       3.99
# 7        Latte          30       5.99
# 8     Espresso          45       3.99
# 9        Latte          35       5.99
# 10    Espresso          45       3.99
# 11       Latte          35       5.99
# 12    Espresso          45       3.99
# 13       Latte          35       5.99

# %%
coffee["Ravenue"] = coffee["Units Sold"] * coffee["New Price"]

coffee
# Out:
# <ipython-input-64-abcb094cdcbb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coffee["Ravenue"] = coffee["Units Sold"] * coffee["New Price"]
#    Coffee Type  Units Sold  New Price  Ravenue
# 0     Espresso          25       3.99    99.75
# 1        Latte          10       5.99    59.90
# 2     Espresso          30       3.99   119.70
# 3        Latte          20       5.99   119.80
# 4     Espresso          35       3.99   139.65
# 5        Latte          25       5.99   149.75
# 6     Espresso          40       3.99   159.60
# 7        Latte          30       5.99   179.70
# 8     Espresso          45       3.99   179.55
# 9        Latte          35       5.99   209.65
# 10    Espresso          45       3.99   179.55
# ...

# %%
# Rename columns
coffee.rename(columns={"New Price": "Price"}, inplace=True)

coffee
# Out:
# <ipython-input-65-8b7e18ae1cb4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coffee.rename(columns={"New Price": "Price"}, inplace=True)
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso          25   3.99    99.75
# 1        Latte          10   5.99    59.90
# 2     Espresso          30   3.99   119.70
# 3        Latte          20   5.99   119.80
# 4     Espresso          35   3.99   139.65
# 5        Latte          25   5.99   149.75
# 6     Espresso          40   3.99   159.60
# 7        Latte          30   5.99   179.70
# 8     Espresso          45   3.99   179.55
# 9        Latte          35   5.99   209.65
# 10    Espresso          45   3.99   179.55
# 11       Latte          35   5.99   209.65
# 12    Espresso          45   3.99   179.55
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new = bios.copy()

# %%
bios_new["first_name"] = bios_new["name"].str.split(" ").str[0]

bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.query("first_name == 'Keith'")
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.2+ MB

# %%
bios_new["born_datetime"] = pd.to_datetime(bios_new["born_date"], errors="coerce", format="%Y-%m-%d")
bios_new["died_datetime"] = pd.to_datetime(bios_new["died_date"], errors="coerce", format="%Y-%m-%d")

bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime died_datetime
# 0  1960-10-02  Jean-François    1886-12-12    1960-10-02
# 1         NaN         Arnaud    1969-04-01           NaT
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
#  12  died_datetime  33940 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(1), object(8)
# memory usage: 14.4+ MB

# %%
bios_new["born_year"] = bios_new["born_datetime"].dt.year

bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime died_datetime  born_year
# 0  1960-10-02  Jean-François    1886-12-12    1960-10-02     1886.0
# ...

# %%
# Save updated DataFrame
bios_new.to_csv("bios_new.csv", index=False)

# %%
# .apply()
bios["height_category"] = bios["height_cm"].apply(lambda x: "Tall" if x > 200 else "Short")

# %%
bios[bios["height_category"] == "Tall"]
# Out:
#         athlete_id                name   born_date         born_city  \
# 1080          1087      Bozhil Lozanov  1934-08-16               NaN
# 1673          1680    Alexis Rubalcaba  1972-08-09  Pedro Betancourt
# 2647          2659       Milan Šrejber  1963-12-30    Praha (Prague)
# 2827          2839  Nik'oloz Deriugini  1959-04-30           Kutaisi
# 2832          2844       Elşad Qadaşev  1968-05-01              Bakı
# ...            ...                 ...         ...               ...
# 143784      147440  Daniel Miklasevich  1997-07-17               NaN
# 143833      147489  Garrett Muagututia  1988-02-26               NaN
# 143834      147490         Kyle Ensing  1997-03-06               NaN
# 143835      147491         Mitch Stahl  1994-08-31               NaN
# 143919      147577   Emerson Rodríguez  1993-02-02           Caracas
#
#                born_region born_country             NOC  height_cm  weight_kg  \
# ...

# %%
def categorize_athlete(row):
    if row["height_cm"] < 175 and row["weight_kg"] < 70:
        return "Ligthweight"
    elif row["height_cm"] < 185 or row["weight_kg"] <= 80:
        return "Mediumweight"
    else:
        return "Heavyweight"

bios["category"] = bios.apply(categorize_athlete, axis=1)

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# # Merging & Concatenating Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category
# 0  1960-10-02           Short   Heavyweight
# 1         NaN           Short  Mediumweight
# 2  1994-07-17           Short  Mediumweight
# ...

# %%
nocs = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/data/noc_regions.csv")

nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new = pd.merge(bios, nocs, how="left", left_on="born_country", right_on="NOC",
                    # suffixes=["_bios", "_noc"]
                    )

bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category NOC_y  region notes
# 0  1960-10-02           Short   Heavyweight   FRA  France   NaN
# ...

# %%
bios_new.rename(columns={'region': 'born_country_full'}, inplace=True)

# %%
bios_new[bios_new['NOC_x'] != bios_new['born_country_full']][['name', 'NOC_x', 'born_country_full']]
# Out:
#                        name    NOC_x born_country_full
# 4              Albert Canet   France                UK
# 12                J. Defert   France               NaN
# 13           Étienne Durand   France               NaN
# 16               Guy Forget   France           Morocco
# 27       Guy, Baron Lejeune   France               NaN
# ...                     ...      ...               ...
# 145491        Matthew Wepke  Jamaica               NaN
# 145493   Landysh Falyakhova      ROC            Russia
# 145495    Polina Luchnikova      ROC            Russia
# 145496  Valeriya Merkusheva      ROC            Russia
# 145497      Yuliya Smirnova      ROC            Russia
#
# [73210 rows x 3 columns]

# %%
usa = bios[bios['born_country'] == 'USA'].copy()

usa.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_category      category
# 54             Short  Mediumweight
# ...

# %%
gbr = bios[bios['born_country'] == 'GBR'].copy()

gbr.head()
# Out:
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country            NOC  height_cm  weight_kg   died_date  \
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
# 38          GBR  Great Britain        NaN        NaN  1972-05-10
# 39          GBR  Great Britain        NaN        NaN  1970-02-22
# 40          GBR  Great Britain      175.0       64.0         NaN
#
#    height_category      category
# 4            Short   Heavyweight
# 37           Short   Heavyweight
# 38           Short   Heavyweight
# ...

# %%
new_df = pd.concat([usa, gbr])

new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        height_category      category
# ...

# %%
results = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/data/results.csv")

results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
combine = pd.merge(results, bios, how="left", on="athlete_id")

combine.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied  ...   born_date born_city  \
# 0           1  FRA              NaN   17.0   True  ...  1886-12-12  Bordeaux
# 1           1  FRA   Jean Montariol    NaN  False  ...  1886-12-12  Bordeaux
# 2           1  FRA              NaN   32.0   True  ...  1886-12-12  Bordeaux
# 3           1  FRA  Jeanne Vaussard    8.0   True  ...  1886-12-12  Bordeaux
# 4           1  FRA  Jacques Brugnon    4.0  False  ...  1886-12-12  Bordeaux
#
# ...

# %% [markdown]
# # Handling Null Values

# %%
coffee.head()
# Out:
#   Coffee Type  Units Sold  Price  Ravenue
# 0    Espresso          25   3.99    99.75
# 1       Latte          10   5.99    59.90
# 2    Espresso          30   3.99   119.70
# 3       Latte          20   5.99   119.80
# 4    Espresso          35   3.99   139.65

# %%
coffee.loc[[2, 3], 'Units Sold'] = np.nan

# %%
coffee
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso        25.0   3.99    99.75
# 1        Latte        10.0   5.99    59.90
# 2     Espresso         NaN   3.99   119.70
# 3        Latte         NaN   5.99   119.80
# 4     Espresso        35.0   3.99   139.65
# 5        Latte        25.0   5.99   149.75
# 6     Espresso        40.0   3.99   159.60
# 7        Latte        30.0   5.99   179.70
# 8     Espresso        45.0   3.99   179.55
# 9        Latte        35.0   5.99   209.65
# 10    Espresso        45.0   3.99   179.55
# 11       Latte        35.0   5.99   209.65
# 12    Espresso        45.0   3.99   179.55
# 13       Latte        35.0   5.99   209.65

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Coffee Type  14 non-null     object
#  1   Units Sold   12 non-null     float64
#  2   Price        14 non-null     float64
#  3   Ravenue      14 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 576.0+ bytes

# %%
coffee.isna().sum()
# Out:
# Coffee Type    0
# Units Sold     2
# Price          0
# Ravenue        0
# dtype: int64

# %%
coffee.fillna(coffee['Units Sold'].mean())
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso       25.00   3.99    99.75
# 1        Latte       10.00   5.99    59.90
# 2     Espresso       33.75   3.99   119.70
# 3        Latte       33.75   5.99   119.80
# 4     Espresso       35.00   3.99   139.65
# 5        Latte       25.00   5.99   149.75
# 6     Espresso       40.00   3.99   159.60
# 7        Latte       30.00   5.99   179.70
# 8     Espresso       45.00   3.99   179.55
# 9        Latte       35.00   5.99   209.65
# 10    Espresso       45.00   3.99   179.55
# 11       Latte       35.00   5.99   209.65
# 12    Espresso       45.00   3.99   179.55
# 13       Latte       35.00   5.99   209.65

# %%
coffee.loc[[2, 3], 'Units Sold'] = np.nan

# %%
coffee.fillna(coffee['Units Sold'].interpolate())
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso        25.0   3.99    99.75
# 1        Latte        10.0   5.99    59.90
# 2     Espresso         NaN   3.99   119.70
# 3        Latte         NaN   5.99   119.80
# 4     Espresso        35.0   3.99   139.65
# 5        Latte        25.0   5.99   149.75
# 6     Espresso        40.0   3.99   159.60
# 7        Latte        30.0   5.99   179.70
# 8     Espresso        45.0   3.99   179.55
# 9        Latte        35.0   5.99   209.65
# 10    Espresso        45.0   3.99   179.55
# 11       Latte        35.0   5.99   209.65
# 12    Espresso        45.0   3.99   179.55
# 13       Latte        35.0   5.99   209.65

# %%
coffee.dropna(subset=['Units Sold'])
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso        25.0   3.99    99.75
# 1        Latte        10.0   5.99    59.90
# 4     Espresso        35.0   3.99   139.65
# 5        Latte        25.0   5.99   149.75
# 6     Espresso        40.0   3.99   159.60
# 7        Latte        30.0   5.99   179.70
# 8     Espresso        45.0   3.99   179.55
# 9        Latte        35.0   5.99   209.65
# 10    Espresso        45.0   3.99   179.55
# 11       Latte        35.0   5.99   209.65
# 12    Espresso        45.0   3.99   179.55
# 13       Latte        35.0   5.99   209.65

# %%
coffee
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso        25.0   3.99    99.75
# 1        Latte        10.0   5.99    59.90
# 2     Espresso         NaN   3.99   119.70
# 3        Latte         NaN   5.99   119.80
# 4     Espresso        35.0   3.99   139.65
# 5        Latte        25.0   5.99   149.75
# 6     Espresso        40.0   3.99   159.60
# 7        Latte        30.0   5.99   179.70
# 8     Espresso        45.0   3.99   179.55
# 9        Latte        35.0   5.99   209.65
# 10    Espresso        45.0   3.99   179.55
# 11       Latte        35.0   5.99   209.65
# 12    Espresso        45.0   3.99   179.55
# 13       Latte        35.0   5.99   209.65

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
#   Coffee Type  Units Sold  Price  Ravenue
# 2    Espresso         NaN   3.99    119.7
# 3       Latte         NaN   5.99    119.8

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso        25.0   3.99    99.75
# 1        Latte        10.0   5.99    59.90
# 4     Espresso        35.0   3.99   139.65
# 5        Latte        25.0   5.99   149.75
# 6     Espresso        40.0   3.99   159.60
# 7        Latte        30.0   5.99   179.70
# 8     Espresso        45.0   3.99   179.55
# 9        Latte        35.0   5.99   209.65
# 10    Espresso        45.0   3.99   179.55
# 11       Latte        35.0   5.99   209.65
# 12    Espresso        45.0   3.99   179.55
# 13       Latte        35.0   5.99   209.65

# %% [markdown]
# # Aggregating Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category
# 0  1960-10-02           Short   Heavyweight
# 1         NaN           Short  Mediumweight
# 2  1994-07-17           Short  Mediumweight
# ...

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Bodrogkisfalud        1
# Ternberg              1
# Klaus                 1
# Plaški                1
# Dulwich Hill          1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country'] == 'USA']['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Pennsylvania             530
# Massachusetts            530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
bios.groupby('born_country')['height_cm'].mean()
# Out:
# born_country
# AFG       170.416667
# AGU       186.000000
# ALB       174.657895
# ALG       176.489362
# AND       172.096774
#              ...
# VIN       181.200000
# Vienna    171.000000
# YEM       169.000000
# ZAM       173.192308
# ZIM       173.540000
# Name: height_cm, Length: 236, dtype: float64

# %%
coffee
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso        25.0   3.99    99.75
# 1        Latte        10.0   5.99    59.90
# 2     Espresso         NaN   3.99   119.70
# 3        Latte         NaN   5.99   119.80
# 4     Espresso        35.0   3.99   139.65
# 5        Latte        25.0   5.99   149.75
# 6     Espresso        40.0   3.99   159.60
# 7        Latte        30.0   5.99   179.70
# 8     Espresso        45.0   3.99   179.55
# 9        Latte        35.0   5.99   209.65
# 10    Espresso        45.0   3.99   179.55
# 11       Latte        35.0   5.99   209.65
# 12    Espresso        45.0   3.99   179.55
# 13       Latte        35.0   5.99   209.65

# %%
coffee['Units Sold'].interpolate(inplace=True)
# Out:
# <ipython-input-106-39b06d2bf99d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coffee['Units Sold'].interpolate(inplace=True)

# %%
coffee
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso   25.000000   3.99    99.75
# 1        Latte   10.000000   5.99    59.90
# 2     Espresso   18.333333   3.99   119.70
# 3        Latte   26.666667   5.99   119.80
# 4     Espresso   35.000000   3.99   139.65
# 5        Latte   25.000000   5.99   149.75
# 6     Espresso   40.000000   3.99   159.60
# 7        Latte   30.000000   5.99   179.70
# 8     Espresso   45.000000   3.99   179.55
# 9        Latte   35.000000   5.99   209.65
# 10    Espresso   45.000000   3.99   179.55
# 11       Latte   35.000000   5.99   209.65
# 12    Espresso   45.000000   3.99   179.55
# 13       Latte   35.000000   5.99   209.65

# %%
coffee.groupby('Coffee Type')['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    253.333333
# Latte       196.666667
# Name: Units Sold, dtype: float64

# %%
coffee.groupby('Coffee Type')['Units Sold'].agg(['sum', 'mean', 'count'])
# Out:
#                     sum       mean  count
# Coffee Type
# Espresso     253.333333  36.190476      7
# Latte        196.666667  28.095238      7

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold': 'sum', 'Price': 'mean'})
# Out:
#              Units Sold  Price
# Coffee Type
# Espresso     253.333333   3.99
# Latte        196.666667   5.99

# %%
coffee.groupby(['Coffee Type', 'Ravenue']).agg({'Units Sold': 'sum', 'Price': 'mean'})
# Out:
#                      Units Sold  Price
# Coffee Type Ravenue
# Espresso    99.75     25.000000   3.99
#             119.70    18.333333   3.99
#             139.65    35.000000   3.99
#             159.60    40.000000   3.99
#             179.55   135.000000   3.99
# Latte       59.90     10.000000   5.99
#             119.80    26.666667   5.99
#             149.75    25.000000   5.99
#             179.70    30.000000   5.99
#             209.65   105.000000   5.99

# %%
coffee
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso   25.000000   3.99    99.75
# 1        Latte   10.000000   5.99    59.90
# 2     Espresso   18.333333   3.99   119.70
# 3        Latte   26.666667   5.99   119.80
# 4     Espresso   35.000000   3.99   139.65
# 5        Latte   25.000000   5.99   149.75
# 6     Espresso   40.000000   3.99   159.60
# 7        Latte   30.000000   5.99   179.70
# 8     Espresso   45.000000   3.99   179.55
# 9        Latte   35.000000   5.99   209.65
# 10    Espresso   45.000000   3.99   179.55
# 11       Latte   35.000000   5.99   209.65
# 12    Espresso   45.000000   3.99   179.55
# 13       Latte   35.000000   5.99   209.65

# %%
coffee.pivot_table(index='Ravenue', columns='Coffee Type', values='Units Sold', aggfunc='sum')
# Out:
# Coffee Type    Espresso       Latte
# Ravenue
# 59.90               NaN   10.000000
# 99.75         25.000000         NaN
# 119.70        18.333333         NaN
# 119.80              NaN   26.666667
# 139.65        35.000000         NaN
# 149.75              NaN   25.000000
# 159.60        40.000000         NaN
# 179.55       135.000000         NaN
# 179.70              NaN   30.000000
# 209.65              NaN  105.000000

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category
# 0  1960-10-02           Short   Heavyweight
# 1         NaN           Short  Mediumweight
# 2  1994-07-17           Short  Mediumweight
# ...

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])

# %%
bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 5       1838.0     1
# 4       1837.0     1
# 3       1836.0     1
# 2       1833.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %%
bios['month_born'] = bios['born_date'].dt.month
bios['year_born'] = bios['born_date'].dt.year

# %%
bios.groupby([bios['year_born'], bios['month_born']])['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#       year_born  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1629     1986.0         1.0   227
# 1497     1975.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 95       1857.0         5.0     1
# 96       1857.0         7.0     1
# 97       1857.0         8.0     1
# 98       1857.0         9.0     1
# 1884     2009.0         1.0     1
#
# [1885 rows x 3 columns]

# %% [markdown]
# # Advanced Functionality

# %%
coffee
# Out:
#    Coffee Type  Units Sold  Price  Ravenue
# 0     Espresso   25.000000   3.99    99.75
# 1        Latte   10.000000   5.99    59.90
# 2     Espresso   18.333333   3.99   119.70
# 3        Latte   26.666667   5.99   119.80
# 4     Espresso   35.000000   3.99   139.65
# 5        Latte   25.000000   5.99   149.75
# 6     Espresso   40.000000   3.99   159.60
# 7        Latte   30.000000   5.99   179.70
# 8     Espresso   45.000000   3.99   179.55
# 9        Latte   35.000000   5.99   209.65
# 10    Espresso   45.000000   3.99   179.55
# 11       Latte   35.000000   5.99   209.65
# 12    Espresso   45.000000   3.99   179.55
# 13       Latte   35.000000   5.99   209.65

# %%
coffee['Yesterday Ravenue'] = coffee['Ravenue'].shift(2)

coffee
# Out:
#    Coffee Type  Units Sold  Price  Ravenue  Yesterday Ravenue
# 0     Espresso   25.000000   3.99    99.75                NaN
# 1        Latte   10.000000   5.99    59.90                NaN
# 2     Espresso   18.333333   3.99   119.70              99.75
# 3        Latte   26.666667   5.99   119.80              59.90
# 4     Espresso   35.000000   3.99   139.65             119.70
# 5        Latte   25.000000   5.99   149.75             119.80
# 6     Espresso   40.000000   3.99   159.60             139.65
# 7        Latte   30.000000   5.99   179.70             149.75
# 8     Espresso   45.000000   3.99   179.55             159.60
# 9        Latte   35.000000   5.99   209.65             179.70
# 10    Espresso   45.000000   3.99   179.55             179.55
# 11       Latte   35.000000   5.99   209.65             209.65
# 12    Espresso   45.000000   3.99   179.55             179.55
# 13       Latte   35.000000   5.99   209.65             209.65

# %%
coffee['Percent Change'] = coffee['Ravenue'].pct_change()

coffee
# Out:
#    Coffee Type  Units Sold  Price  Ravenue  Yesterday Ravenue  Percent Change
# 0     Espresso   25.000000   3.99    99.75                NaN             NaN
# 1        Latte   10.000000   5.99    59.90                NaN       -0.399499
# 2     Espresso   18.333333   3.99   119.70              99.75        0.998331
# 3        Latte   26.666667   5.99   119.80              59.90        0.000835
# 4     Espresso   35.000000   3.99   139.65             119.70        0.165693
# 5        Latte   25.000000   5.99   149.75             119.80        0.072324
# 6     Espresso   40.000000   3.99   159.60             139.65        0.065776
# 7        Latte   30.000000   5.99   179.70             149.75        0.125940
# 8     Espresso   45.000000   3.99   179.55             159.60       -0.000835
# 9        Latte   35.000000   5.99   209.65             179.70        0.167641
# 10    Espresso   45.000000   3.99   179.55             179.55       -0.143573
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category      category  month_born  year_born
# 0  1960-10-02           Short   Heavyweight        12.0     1886.0
# ...

# %%
bios['height_rank'] = bios['height_cm'].rank(ascending=False)

bios.sort_values('height_rank')
# Out:
#         athlete_id                   name  born_date           born_city  \
# 89070        89782               Yao Ming 1980-09-12      Xuhui District
# 6978          7013        Arvydas Sabonis 1964-12-19              Kaunas
# 5781          5804         Tommy Burleson 1952-02-24           Crossnore
# 120266      122147           Zhang Zhaoxu 1987-11-18             Binzhou
# 89075        89787         Roberto Dueñas 1975-11-01              Madrid
# ...            ...                    ...        ...                 ...
# 145490      149217            Sin Ye-Chan 1995-06-13                 NaN
# 145491      149218          Matthew Wepke 1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez 1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova 1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips 1913-07-15        Dulwich Hill
#
#                  born_region born_country                         NOC  \
# ...

# %%
coffee.head()
# Out:
#   Coffee Type  Units Sold  Price  Ravenue  Yesterday Ravenue  Percent Change
# 0    Espresso   25.000000   3.99    99.75                NaN             NaN
# 1       Latte   10.000000   5.99    59.90                NaN       -0.399499
# 2    Espresso   18.333333   3.99   119.70              99.75        0.998331
# 3       Latte   26.666667   5.99   119.80              59.90        0.000835
# 4    Espresso   35.000000   3.99   139.65             119.70        0.165693

# %%
coffee['Cumalative Sum'] = coffee['Ravenue'].cumsum()

coffee
# Out:
#    Coffee Type  Units Sold  Price  Ravenue  Yesterday Ravenue  Percent Change  \
# 0     Espresso   25.000000   3.99    99.75                NaN             NaN
# 1        Latte   10.000000   5.99    59.90                NaN       -0.399499
# 2     Espresso   18.333333   3.99   119.70              99.75        0.998331
# 3        Latte   26.666667   5.99   119.80              59.90        0.000835
# 4     Espresso   35.000000   3.99   139.65             119.70        0.165693
# 5        Latte   25.000000   5.99   149.75             119.80        0.072324
# 6     Espresso   40.000000   3.99   159.60             139.65        0.065776
# 7        Latte   30.000000   5.99   179.70             149.75        0.125940
# 8     Espresso   45.000000   3.99   179.55             159.60       -0.000835
# 9        Latte   35.000000   5.99   209.65             179.70        0.167641
# 10    Espresso   45.000000   3.99   179.55             179.55       -0.143573
# ...

# %%
latte = coffee[coffee['Coffee Type'] == 'Latte']

latte['3 Day'] = latte['Units Sold'].rolling(3).sum()

latte
# Out:
# <ipython-input-142-cea27ca08e09>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latte['3 Day'] = latte['Units Sold'].rolling(3).sum()
#    Coffee Type  Units Sold  Price  Ravenue  Yesterday Ravenue  Percent Change  \
# 1        Latte   10.000000   5.99    59.90                NaN       -0.399499
# 3        Latte   26.666667   5.99   119.80              59.90        0.000835
# 5        Latte   25.000000   5.99   149.75             119.80        0.072324
# 7        Latte   30.000000   5.99   179.70             149.75        0.125940
# 9        Latte   35.000000   5.99   209.65             179.70        0.167641
# 11       Latte   35.000000   5.99   209.65             209.65        0.167641
# ...
